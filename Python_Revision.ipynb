# %% [markdown]
# # Comments

# %%
"""
single line comment
Multiline comment
"""
# Out:
# '\nsingle line comment\nMultiline comment\n'

# %%
a = 4
a = 5
z = a + a
print(z)
# Out:
# 10

# %% [markdown]
# # Take Input From Users

# %% [markdown]
# a = int(input())
# b = int(input())
# c = int(input())
# z = a + b + c
# print(z)

# %% [markdown]
# # Variable Creation
# # It can be combination of Alphabet,digit and under_score
# # First letter can't be digit.
# # a-2 can't use.
# # (a -z, A-Z)

# %%
_b = 12 # No problem in creation but not recommended.
z = _b +_b
print(z)
# Out:
# 24

# %% [markdown]
# # Python is case - sensetive Laungage

# %%
'''
y = 5 # Here is small letter
x = 6
c = Y + x # Here i am trying to print(Y + x).Getting an error bcz of case sensetive.
print(c)
'''
# Out:
# '\ny = 5 # Here is small letter\nx = 6\nc = Y + x # Here i am trying to print(Y + x).Getting an error bcz of case sensetive.\nprint(c)\n'

# %% [markdown]
# # Data Type

# %%
#1. Numbers ------int(34, -245, 0)
#2.               float(4.5, 4.0, 0.004, -2.13)
#3.               complex(3 + 4j, -5+6j, 2.1-43.5j
# int, float and complex are pre- defined classes.

#2.Boolean---------bool| True, False

# %% [markdown]
# # Output Using Print Method

# %%
print("Welcome")
x = 5
print(x)
y = 4.5
print(x,y,20)# To print multiple values
print(x + y + 1)# To print the value of expression
# Out:
# Welcome
# 5
# 5 4.5 20
# 10.5

# %% [markdown]
# # To print formatted text contaning variables

# %%
a = 5
b = 4
print("sum of %d and %d is %d"%(a,b,a+b))
print("sum of",a,"and",b,"is",a+b)
# Out:
# sum of 5 and 4 is 9
# sum of 5 and 4 is 9

# %%
r = 10
q = 20
s = 30
print(r, q, s, sep ='-') #U can use seprator in print function
print(r, sep =' ',end=' \t')
print(q, end ='\n\n\n\n') #slac n will change the line .Here it will change the line four times.
print(s)
# Out:
# 10-20-30
# 10 	20
#
#
#
# 30

# %% [markdown]
# # Escape Sequences

# %%
'''
\n -----New Line
\t-----Tab space
\r-----Carriage Return
\b-----Backspace
\\-----print\
\"-----print "
\'-----print '
'''
# Out:
# '\n\n -----New Line\n\t-----Tab space\n\r-----Carriage Return\n\x08-----Backspace\n\\-----print"-----print "\n\'-----print \'\n'

# %% [markdown]
# # Simple Problems on Print

# %% [markdown]
# # 1.Write a python script to print YOUR NAME on the screen

# %%
print("Ranveer Allahabadiya")
# Out:
# Ranveer Allahabadiya

# %% [markdown]
# # write a python script to print YOUR NAME on the first line and Education Services on second line.

# %%
print("Ranveer Allahabadiya")
print("Education Services")
# Out:
# Ranveer Allahabadiya
# Education Services

# %% [markdown]
# # 3.write a python script to print Your Name on screen.(Remember to print double quote)

# %%
print("\"Ranveer Allahabadiya\"") #First Ways
print('"Ranveer Allahabadiya"')# Second Ways
# Out:
# "Ranveer Allahabadiya"
# "Ranveer Allahabadiya"

# %% [markdown]
# # 4.Write a python script to print "Office Day" on the screen(Remember to print double quote)

# %%
print("\"Office Day\"")
print('"Office Day"')
# Out:
# "Office Day"
# "Office Day"

# %% [markdown]
# # 5.write a python script to print \n on the screen.

# %%
print("\\n")
# Out:
# \n

# %% [markdown]
# # Module ,Package And Library

# %%
'''Module----File with .py extension is Module.
Package--- collection of Modules(or packages,folder inside folder)
Library --- Collection of Packages.'''
# Out:
# 'Module----File with .py extension is Module.\nPackage--- collection of Modules(or packages,folder inside folder)\nLibrary --- Collection of Packages.'

# %% [markdown]
# # Keyword,help()

# %%
import keyword
print(keyword.kwlist)
print(keyword.softkwlist)#Python introduced soft keywords mainly for pattern matching features (Python 3.10+).
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# ['_', 'case', 'match', 'type']

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  keywords
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# ...

# %%
x = False
y = True
z = None
